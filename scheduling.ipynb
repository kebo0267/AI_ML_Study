# %% [markdown]
# Capstone Project 1.
# Creating Task Manager with User Authentication
# Project consist of four python files and one notebook.
# DemoMenu.py, TaskRecord.py, UserList.py and UserInfo.py
# scheduling.ipynb

# %%
# %run DemoMenu.py
# Out:
# ...
# userId
# userName
# password
# lastLogin
# failedLogin
# failedCount
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/local_prog/AI_ML_Study/DemoMenu.py:79
#      77 if __name__ == "__main__":
#      78     menu = DemoMenu()
# ---> 79     menu.mainMenu()
#
# File ~/local_prog/AI_ML_Study/DemoMenu.py:68, in DemoMenu.mainMenu(self)
#      66     self.pick_login()
#      67 elif menuIndx == 1:
# ---> 68     self.pick_signup()
#      69 else:
#      70     continue
#
# File ~/local_prog/AI_ML_Study/DemoMenu.py:47, in DemoMenu.pick_signup(self)
#      45     print(f'Invalid Password: {comment}')
#      46     continue
# ---> 47 self.userList.addUser(userName,password)
#      48 break
#
# File ~/local_prog/AI_ML_Study/UserList.py:17, in UserList.addUser(self, userName, password)
#      15 self.userList.append(user)
#      16 self.nextUserId += 1
# ---> 17 self.saveRecords()
# ...
