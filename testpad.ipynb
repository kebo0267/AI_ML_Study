# %%
# %run DemoMenu.py
# Out:
# [0] - Sign In
# [1] - Sign Up
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/local_prog/AI_ML_Study/DemoMenu.py:79
#      77 if __name__ == "__main__":
#      78     menu = DemoMenu()
# ---> 79     menu.mainMenu()
#
# File ~/local_prog/AI_ML_Study/DemoMenu.py:59, in DemoMenu.mainMenu(self)
#      56 for optIndex in range(0,len(menuOptions)):
#      57     print(f'[{optIndex}] - {menuOptions[optIndex]}')
# ---> 59 value = input("Choose Option: ")
#      60 try:
#      61     menuIndx = int(value)
#
# File ~/local_prog/AI_ML_Study/.venv/lib64/python3.12/site-packages/ipykernel/kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
# ...
