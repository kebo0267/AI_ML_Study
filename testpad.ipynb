# %%
from datetime import datetime
import json

test = {}
#The date of the expense in the format YYYY-MM-DD

test["demotime"] = datetime.now()
if type(test["demotime"]) == datetime:
    print("date time object")
else:
    print("Nope")
# Out:
# date time object
